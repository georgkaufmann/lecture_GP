# %% [markdown]
# <table>
# <tr>
#     <td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
#     <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">AG Dynamics of the Earth</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Jupyter notebooks</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# </tr>
# </table>

# %% [markdown]
# # Geophysikalisches Praktikum: Create coordinates and elevation data -ERT-
#
# ## Create coordinates and elevation data
# ----
# *Georg Kaufmann,
# Geophysics Section,
# Institute of Geological Sciences,
# Freie Universität Berlin,
# Germany*

# %%
import numpy as np
import matplotlib.pyplot as plt
import libGP

# %% [markdown]
# ----
# ## Read **elevation** data in `geodyn` format
# We first need to load elevation data (in `geodyn5` format), which are needed for interpolating the
# elevation section of the profile.

# %%
easting,northing,elevation = libGP.readTopography('2Dm_GP2022_DTM.xy',path='data/BlaueKuppe/',iskip=20,control=True,plot=False)
# Out:
# File read:                  data/BlaueKuppe/2Dm_GP2022_DTM.xy
# Number of topo lines:       22509
# Number of meta-data read:   9
# Number of topo data read:   1125
# min/max easting:            571595.42 572995.42
# min/max northing:           5667007.78 5668497.78
# min/max elevation:          216.0 322.0

# %% [markdown]
# ----
# ## Create **coordinate** file
# We use a set of manually taken GPS points along a profile, which need to be stored in a `numpy`array:

# %% [raw]
# GPSPoints = np.array([
# [572637.000,5667728.000],
# [572516.392,5667695.155],
# [572413.000,5667667.000]
# ])

# %%
help(libGP.createERTCoordElevation)

# %% [markdown]
# Then we define the number of electrode, `nElectrodes`, and the electrode spacing, `sElectrodes`.
#
# A name is needed for the output profile data set, `ertProfile`.

# %%
ertProfile  = 'GP2022_ERT01_WenSchlum'
nElectrodes = 50
sElectrodes = 5
GPSPoints = np.array([
[572637.000,5667728.000],
[572516.392,5667695.155],
[572413.000,5667667.000]
])

elecPoints = libGP.createERTCoordElevation(ertProfile,nElectrodes,sElectrodes,GPSPoints,easting,northing,elevation,
                                           path='tmp/',control=True,plot=True)
# Out:
# nameERT:                    GP2022_ERT01_WenSchlum
# nElectrodes:                50
# sElectrodes:                5
# Profile length:             245  m
# GPS points:                 3
# GPSDistance:                232.15727428351698
# extrapolate last point
# [[ 572637.         5667728.        ]
#  [ 572516.392      5667695.155     ]
#  [ 572400.60850111 5667663.62563205]]
# GPSDistance:                244.99999999992968
#    0 572637.00000000 5667728.00000000   282.75     0.00
#    1 572632.17569292 5667726.68620352   282.90     5.00
#    2 572627.35138584 5667725.37240704   283.04    10.00
#    3 572622.52707876 5667724.05861055   283.29    15.00
#    4 572617.70277168 5667722.74481407   283.61    20.00
#    5 572612.87846460 5667721.43101759   283.94    25.00
#    6 572608.05415752 5667720.11722111   284.26    30.00
#    7 572603.22985044 5667718.80342463   284.59    35.00
#    8 572598.40554336 5667717.48962815   284.91    40.00
#    9 572593.58123628 5667716.17583167   285.18    45.00
#   10 572588.75692920 5667714.86203518   285.36    50.00
#   11 572583.93262212 5667713.54823870   285.54    55.00
#   12 572579.10831504 5667712.23444222   285.72    60.00
#   13 572574.28400796 5667710.92064574   285.90    65.00
#   14 572569.45970088 5667709.60684926   286.23    70.00
#   15 572564.63539380 5667708.29305278   286.77    75.00
#   16 572559.81108672 5667706.97925629   287.31    80.00
#   17 572554.98677963 5667705.66545981   287.85    85.00
#   18 572550.16247255 5667704.35166333   288.39    90.00
#   19 572545.33816547 5667703.03786685   288.93    95.00
#   20 572540.51385839 5667701.72407037   289.29   100.00
#   21 572535.68955131 5667700.41027389   289.58   105.00
#   22 572530.86524423 5667699.09647741   289.87   110.00
#   23 572526.04093715 5667697.78268092   290.16   115.00
#   24 572521.21663007 5667696.46888444   290.45   120.00
#   25 572516.39232299 5667695.15508796   291.06   125.00
#   26 572511.56799708 5667693.84136063   292.43   130.00
#   27 572506.74367117 5667692.52763330   293.79   135.00
#   28 572501.91934526 5667691.21390597   295.16   140.00
#   29 572497.09501935 5667689.90017864   296.53   145.00
#   30 572492.27069343 5667688.58645131   297.30   150.00
#   31 572487.44636752 5667687.27272398   297.75   155.00
#   32 572482.62204161 5667685.95899665   298.20   160.00
#   33 572477.79771570 5667684.64526932   298.65   165.00
#   34 572472.97338979 5667683.33154199   299.10   170.00
#   35 572468.14906388 5667682.01781466   299.55   175.00
#   36 572463.32473796 5667680.70408733   299.94   180.00
#   37 572458.50041205 5667679.39036000   300.03   185.00
#   38 572453.67608614 5667678.07663267   300.12   190.00
#   39 572448.85176023 5667676.76290534   300.22   195.00
#   40 572444.02743432 5667675.44917801   300.31   200.00
#   41 572439.20310840 5667674.13545068   300.40   205.00
#   42 572434.37878249 5667672.82172335   300.49   210.00
#   43 572429.55445658 5667671.50799603   300.58   215.00
#   44 572424.73013067 5667670.19426870   300.47   220.00
#   45 572419.90580476 5667668.88054137   300.22   225.00
#   46 572415.08147884 5667667.56681404   299.98   230.00
#   47 572410.25715293 5667666.25308671   299.76   235.00
#   48 572405.43282702 5667664.93935938   300.24   240.00
#   49 572400.60850111 5667663.62563205   300.71   245.00
# nameERT:                    GP2022_ERT01_WenSchlum
# File written:               tmp/GP2022_ERT01_WenSchlum.profile

# %%
help(libGP.createGPRCoordElevation)

# %%
gprProfile = 'GP2022_GPR01'
lProfile   = 78
sProfile   = 1
traceInc   = 0.01
GPSPoints  = np.array([
[572637.000,5667728.000],
[572413.000,5667667.000]
])

gprPoints = libGP.createGPRCoordElevation(gprProfile,lProfile,sProfile,GPSPoints,easting,northing,elevation,traceInc,
                                           path='tmp/',control=True,plot=True)

# %%
help(libGP.createGravityCoordElevation)

# %%
libGP.createGravityCoordElevation('BlaueKuppe.xy',path='tmp/',irepeat=3,control=True,plot=True)

# %% [markdown]
# ----
# ## Add **profile length and elevation** to **ERT data** in `Res2DInv` format

# %%
help(libGP.addERTCoordElevation)

# %%
ertData = 'GP2022_ERT01_WenSchlum.dat'
libGP.addERTCoordElevation(ertData,elecPoints,path='tmp/',control=False)
# Out:
# File read:                  tmp/GP2022_ERT01_WenSchlum.dat
# File written:               tmp/GP2022_ERT01_WenSchlum_mod.dat

# %% [markdown]
# ----
